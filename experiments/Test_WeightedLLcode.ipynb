# %%
# %run radon.py
# Out:
# Normal model
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_062b78cae7e8dcc6349b8a88f7665eba NOW.
# Weighted LL model
#
# weighted but not missing anything
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_062b78cae7e8dcc6349b8a88f7665eba NOW.
# Leaving component = 684
# WARNING:pystan:Maximum (flat) parameter count (1000) exceeded: skipping diagnostic tests for n_eff and Rhat.
# To run all diagnostics call pystan.check_hmc_diagnostics(fit)
